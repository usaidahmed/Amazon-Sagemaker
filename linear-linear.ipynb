# %%
import pandas as pd
dataset = pd.read_csv('Boston.csv')

# %%
print(dataset.shape)
# Out:
# (506, 15)

# %%
dataset[:5]
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3           4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4           5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
#
#    tax  ptratio   black  lstat  medv
# 0  296     15.3  396.90   4.98  24.0
# 1  242     17.8  396.90   9.14  21.6
# 2  242     17.8  392.83   4.03  34.7
# 3  222     18.7  394.63   2.94  33.4
# 4  222     18.7  396.90   5.33  36.2

# %%
dataset = pd.concat([dataset['medv'],
                     dataset.drop(['medv'], axis=1)],
                    axis=1)

# %%
from sklearn.model_selection import train_test_split
training_dataset, validation_dataset = train_test_split(dataset, test_size=0.1)

# %%
training_dataset.to_csv('training_dataset.csv',index=False, header=False)
validation_dataset.to_csv('validation_dataset.csv',index=False, header=False)

# %%
import sagemaker
sess = sagemaker.Session()
bucket = sess.default_bucket()

# %%
prefix = 'boston-housing'
training_data_path = sess.upload_data(path='training_dataset.csv',key_prefix=prefix + '/input/training')
validation_data_path = sess.upload_data(path='validation_dataset.csv',key_prefix=prefix + '/input/validation')
print(training_data_path)
print(validation_data_path)
# Out:
# s3://sagemaker-us-east-2-664224523979/boston-housing/input/training/training_dataset.csv
# s3://sagemaker-us-east-2-664224523979/boston-housing/input/validation/validation_dataset.csv

# %%
import boto3
from sagemaker import image_uris
region = boto3.Session().region_name
container = image_uris.retrieve('linear-learner', region)

# %%
from sagemaker.estimator import Estimator
ll_estimator = Estimator(
    container,
    role=sagemaker.get_execution_role(),
    instance_count=1,
    instance_type='ml.m5.xlarge',
    output_path='s3://{}/{}/output'.format(bucket,
                                           prefix))

# %%
ll_estimator.set_hyperparameters(
    predictor_type='regressor',
    mini_batch_size=32)

# %%
training_data_channel = sagemaker.TrainingInput(
    s3_data=training_data_path,
    content_type='text/csv')

# %%
validation_data_channel = sagemaker.TrainingInput(
    s3_data=validation_data_path,
    content_type='text/csv')

# %%
ll_estimator.fit({'train': training_data_channel,'validation': validation_data_channel})
# Out:
# 2021-04-04 12:10:00 Starting - Starting the training job...
# 2021-04-04 12:10:02 Starting - Launching requested ML instancesProfilerReport-1617538200: InProgress
# ......
# 2021-04-04 12:11:25 Starting - Preparing the instances for training......
# 2021-04-04 12:12:30 Downloading - Downloading input data
# 2021-04-04 12:12:30 Training - Downloading the training image...
# 2021-04-04 12:13:00 Uploading - Uploading generated training modelDocker entrypoint called with argument(s): train
# Running default environment configuration script
# [04/04/2021 12:12:47 INFO 140225025931072] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/resources/default-input.json: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false'}
# [04/04/2021 12:12:47 INFO 140225025931072] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'predictor_type': 'regressor', 'mini_batch_size': '32'}
# [04/04/2021 12:12:47 INFO 140225025931072] Final configuration: {'mini_batch_size': '32', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'regressor'}
# [04/04/2021 12:12:47 WARNING 140225025931072] Loggers have already been setup.
# Process 1 is a worker.
# [04/04/2021 12:12:47 INFO 140225025931072] Using default worker.
# [04/04/2021 12:12:47 INFO 140225025931072] Checkpoint loading and saving are disabled.
# [04/04/2021 12:12:47 INFO 140225025931072] Create Store: local
# [04/04/2021 12:12:47 INFO 140225025931072] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f884e0160d0>
# [04/04/2021 12:12:47 INFO 140225025931072] Scaling model computed with parameters:
#  {'stdev_label':
# [9.310074]
# <NDArray 1 @cpu(0)>, 'stdev_weight':
# [1.45244598e+02 8.97763252e+00 2.35219784e+01 6.91436386e+00
#  2.64826596e-01 1.18811004e-01 6.97966814e-01 2.80776348e+01
#  2.15919423e+00 8.85108852e+00 1.69559052e+02 2.19030571e+00
#  9.48711472e+01 7.15794420e+00]
# <NDArray 14 @cpu(0)>, 'mean_label':
# [22.541739]
# <NDArray 1 @cpu(0)>, 'mean_weight':
# [2.5527681e+02 3.8364496e+00 1.1620536e+01 1.1260001e+01 7.5892851e-02
#  5.5715358e-01 6.3011398e+00 6.8832138e+01 3.8086405e+00 9.7946434e+00
#  4.1238623e+02 1.8427456e+01 3.5473273e+02 1.2600647e+01]
# <NDArray 14 @cpu(0)>}
# [04/04/2021 12:12:47 INFO 140225025931072] nvidia-smi: took 0.031 seconds to run.
# [04/04/2021 12:12:47 INFO 140225025931072] nvidia-smi identified 0 GPUs.
# [04/04/2021 12:12:47 INFO 140225025931072] Number of GPUs being used: 0
# #metrics {"StartTime": 1617538368.0521991, "EndTime": 1617538368.0522368, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 487.0, "count": 1, "min": 487, "max": 487}, "Total Batches Seen": {"sum": 16.0, "count": 1, "min": 16, "max": 16}, "Max Records Seen Between Resets": {"sum": 455.0, "count": 1, "min": 455, "max": 455}, "Max Batches Seen Between Resets": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# #metrics {"StartTime": 1617538368.3006132, "EndTime": 1617538368.300663, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"train_mse_objective": {"sum": 0.8086183347872326, "count": 1, "min": 0.8086183347872326, "max": 0.8086183347872326}}}
#
# #metrics {"StartTime": 1617538368.300729, "EndTime": 1617538368.300742, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"train_mse_objective": {"sum": 0.8048151050295148, "count": 1, "min": 0.8048151050295148, "max": 0.8048151050295148}}}
#
# #metrics {"StartTime": 1617538368.3007772, "EndTime": 1617538368.3007872, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"train_mse_objective": {"sum": 0.717446078147207, "count": 1, "min": 0.717446078147207, "max": 0.717446078147207}}}
#
# #metrics {"StartTime": 1617538368.300823, "EndTime": 1617538368.300833, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"train_mse_objective": {"sum": 0.7238712034055165, "count": 1, "min": 0.7238712034055165, "max": 0.7238712034055165}}}
#
# #metrics {"StartTime": 1617538368.3008673, "EndTime": 1617538368.3008764, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"train_mse_objective": {"sum": 0.8852127705301557, "count": 1, "min": 0.8852127705301557, "max": 0.8852127705301557}}}
#
# #metrics {"StartTime": 1617538368.3009133, "EndTime": 1617538368.300923, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"train_mse_objective": {"sum": 0.9077914868082319, "count": 1, "min": 0.9077914868082319, "max": 0.9077914868082319}}}
#
# #metrics {"StartTime": 1617538368.3009553, "EndTime": 1617538368.3009648, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"train_mse_objective": {"sum": 0.8791220486164093, "count": 1, "min": 0.8791220486164093, "max": 0.8791220486164093}}}
#
# #metrics {"StartTime": 1617538368.300997, "EndTime": 1617538368.301006, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"train_mse_objective": {"sum": 0.8744909146002361, "count": 1, "min": 0.8744909146002361, "max": 0.8744909146002361}}}
#
# #metrics {"StartTime": 1617538368.3010378, "EndTime": 1617538368.3010457, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"train_mse_objective": {"sum": 0.9942288143294198, "count": 1, "min": 0.9942288143294198, "max": 0.9942288143294198}}}
#
# #metrics {"StartTime": 1617538368.3010755, "EndTime": 1617538368.3010838, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"train_mse_objective": {"sum": 0.7181279169661658, "count": 1, "min": 0.7181279169661658, "max": 0.7181279169661658}}}
#
# #metrics {"StartTime": 1617538368.301118, "EndTime": 1617538368.3011277, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"train_mse_objective": {"sum": 0.7092728252921786, "count": 1, "min": 0.7092728252921786, "max": 0.7092728252921786}}}
#
# #metrics {"StartTime": 1617538368.301161, "EndTime": 1617538368.30117, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 11}, "Metrics": {"train_mse_objective": {"sum": 0.7868193430559975, "count": 1, "min": 0.7868193430559975, "max": 0.7868193430559975}}}
#
# #metrics {"StartTime": 1617538368.3012054, "EndTime": 1617538368.3012142, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 12}, "Metrics": {"train_mse_objective": {"sum": 0.8909910172224045, "count": 1, "min": 0.8909910172224045, "max": 0.8909910172224045}}}
#
# #metrics {"StartTime": 1617538368.3012495, "EndTime": 1617538368.3012595, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 13}, "Metrics": {"train_mse_objective": {"sum": 0.8893691599369049, "count": 1, "min": 0.8893691599369049, "max": 0.8893691599369049}}}
#
# #metrics {"StartTime": 1617538368.3012943, "EndTime": 1617538368.3013039, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 14}, "Metrics": {"train_mse_objective": {"sum": 0.8858908606427056, "count": 1, "min": 0.8858908606427056, "max": 0.8858908606427056}}}
#
# #metrics {"StartTime": 1617538368.3013387, "EndTime": 1617538368.3013484, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 15}, "Metrics": {"train_mse_objective": {"sum": 0.8825419843196869, "count": 1, "min": 0.8825419843196869, "max": 0.8825419843196869}}}
#
# #metrics {"StartTime": 1617538368.3013835, "EndTime": 1617538368.3013935, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 16}, "Metrics": {"train_mse_objective": {"sum": 0.7820489598172051, "count": 1, "min": 0.7820489598172051, "max": 0.7820489598172051}}}
#
# #metrics {"StartTime": 1617538368.3014264, "EndTime": 1617538368.3014357, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 17}, "Metrics": {"train_mse_objective": {"sum": 0.7838465826851981, "count": 1, "min": 0.7838465826851981, "max": 0.7838465826851981}}}
#
# #metrics {"StartTime": 1617538368.3014715, "EndTime": 1617538368.301481, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 18}, "Metrics": {"train_mse_objective": {"sum": 0.9572167907442365, "count": 1, "min": 0.9572167907442365, "max": 0.9572167907442365}}}
#
# #metrics {"StartTime": 1617538368.3015153, "EndTime": 1617538368.3015244, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 19}, "Metrics": {"train_mse_objective": {"sum": 0.7704508176871708, "count": 1, "min": 0.7704508176871708, "max": 0.7704508176871708}}}
#
# #metrics {"StartTime": 1617538368.3015575, "EndTime": 1617538368.3015666, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 20}, "Metrics": {"train_mse_objective": {"sum": 0.9044367245265416, "count": 1, "min": 0.9044367245265416, "max": 0.9044367245265416}}}
#
# #metrics {"StartTime": 1617538368.3016012, "EndTime": 1617538368.3016102, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 21}, "Metrics": {"train_mse_objective": {"sum": 0.8999157654387611, "count": 1, "min": 0.8999157654387611, "max": 0.8999157654387611}}}
#
# #metrics {"StartTime": 1617538368.3016443, "EndTime": 1617538368.301654, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 22}, "Metrics": {"train_mse_objective": {"sum": 0.8982355722359249, "count": 1, "min": 0.8982355722359249, "max": 0.8982355722359249}}}
#
# #metrics {"StartTime": 1617538368.3016927, "EndTime": 1617538368.301703, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 23}, "Metrics": {"train_mse_objective": {"sum": 0.9068324033703122, "count": 1, "min": 0.9068324033703122, "max": 0.9068324033703122}}}
#
# #metrics {"StartTime": 1617538368.3017423, "EndTime": 1617538368.3017523, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 24}, "Metrics": {"train_mse_objective": {"sum": 0.9982798227242061, "count": 1, "min": 0.9982798227242061, "max": 0.9982798227242061}}}
#
# #metrics {"StartTime": 1617538368.3017886, "EndTime": 1617538368.3017983, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 25}, "Metrics": {"train_mse_objective": {"sum": 0.9176520918096814, "count": 1, "min": 0.9176520918096814, "max": 0.9176520918096814}}}
#
# #metrics {"StartTime": 1617538368.301831, "EndTime": 1617538368.3018377, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 26}, "Metrics": {"train_mse_objective": {"sum": 0.9895434038979667, "count": 1, "min": 0.9895434038979667, "max": 0.9895434038979667}}}
#
# #metrics {"StartTime": 1617538368.3018577, "EndTime": 1617538368.301863, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 27}, "Metrics": {"train_mse_objective": {"sum": 0.9461359807423183, "count": 1, "min": 0.9461359807423183, "max": 0.9461359807423183}}}
#
# #metrics {"StartTime": 1617538368.30189, "EndTime": 1617538368.3018985, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 28}, "Metrics": {"train_mse_objective": {"sum": 1.177928124155317, "count": 1, "min": 1.177928124155317, "max": 1.177928124155317}}}
#
# #metrics {"StartTime": 1617538368.3019378, "EndTime": 1617538368.301949, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 29}, "Metrics": {"train_mse_objective": {"sum": 1.1460671722888947, "count": 1, "min": 1.1460671722888947, "max": 1.1460671722888947}}}
#
# #metrics {"StartTime": 1617538368.3019893, "EndTime": 1617538368.3019986, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 30}, "Metrics": {"train_mse_objective": {"sum": 1.1889258750847407, "count": 1, "min": 1.1889258750847407, "max": 1.1889258750847407}}}
#
# #metrics {"StartTime": 1617538368.3020372, "EndTime": 1617538368.3020444, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 31}, "Metrics": {"train_mse_objective": {"sum": 1.1760609618255071, "count": 1, "min": 1.1760609618255071, "max": 1.1760609618255071}}}
#
# [04/04/2021 12:12:48 INFO 140225025931072] #quality_metric: host=algo-1, epoch=0, train mse_objective <loss>=0.8086183347872326
# #metrics {"StartTime": 1617538368.3480322, "EndTime": 1617538368.348083, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"validation_mse_objective": {"sum": 35.344003714767155, "count": 1, "min": 35.344003714767155, "max": 35.344003714767155}}}
#
# #metrics {"StartTime": 1617538368.3481505, "EndTime": 1617538368.348163, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"validation_mse_objective": {"sum": 39.7960755591299, "count": 1, "min": 39.7960755591299, "max": 39.7960755591299}}}
#
# #metrics {"StartTime": 1617538368.3482027, "EndTime": 1617538368.3482125, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"validation_mse_objective": {"sum": 40.442253561580884, "count": 1, "min": 40.442253561580884, "max": 40.442253561580884}}}
#
# #metrics {"StartTime": 1617538368.348248, "EndTime": 1617538368.3482578, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"validation_mse_objective": {"sum": 33.117441214767155, "count": 1, "min": 33.117441214767155, "max": 33.117441214767155}}}
#
# #metrics {"StartTime": 1617538368.348293, "EndTime": 1617538368.3483043, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"validation_mse_objective": {"sum": 20.996631697112438, "count": 1, "min": 20.996631697112438, "max": 20.996631697112438}}}
#
# #metrics {"StartTime": 1617538368.3483398, "EndTime": 1617538368.3483486, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"validation_mse_objective": {"sum": 23.816172281901043, "count": 1, "min": 23.816172281901043, "max": 23.816172281901043}}}
#
# #metrics {"StartTime": 1617538368.3483815, "EndTime": 1617538368.3483891, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"validation_mse_objective": {"sum": 23.089334525314033, "count": 1, "min": 23.089334525314033, "max": 23.089334525314033}}}
#
# #metrics {"StartTime": 1617538368.3484232, "EndTime": 1617538368.3484309, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"validation_mse_objective": {"sum": 22.3965669519761, "count": 1, "min": 22.3965669519761, "max": 22.3965669519761}}}
#
# #metrics {"StartTime": 1617538368.3484597, "EndTime": 1617538368.3484678, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"validation_mse_objective": {"sum": 44.12744379978554, "count": 1, "min": 44.12744379978554, "max": 44.12744379978554}}}
#
# #metrics {"StartTime": 1617538368.3485036, "EndTime": 1617538368.3485124, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"validation_mse_objective": {"sum": 38.488056257659316, "count": 1, "min": 38.488056257659316, "max": 38.488056257659316}}}
#
# #metrics {"StartTime": 1617538368.348538, "EndTime": 1617538368.3485436, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"validation_mse_objective": {"sum": 35.426776960784316, "count": 1, "min": 35.426776960784316, "max": 35.426776960784316}}}
#
# #metrics {"StartTime": 1617538368.3485632, "EndTime": 1617538368.3485687, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 11}, "Metrics": {"validation_mse_objective": {"sum": 39.709846047794116, "count": 1, "min": 39.709846047794116, "max": 39.709846047794116}}}
#
# #metrics {"StartTime": 1617538368.3485878, "EndTime": 1617538368.3485928, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 12}, "Metrics": {"validation_mse_objective": {"sum": 23.773442287071077, "count": 1, "min": 23.773442287071077, "max": 23.773442287071077}}}
#
# #metrics {"StartTime": 1617538368.3486118, "EndTime": 1617538368.348617, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 13}, "Metrics": {"validation_mse_objective": {"sum": 22.459553438074447, "count": 1, "min": 22.459553438074447, "max": 22.459553438074447}}}
#
# #metrics {"StartTime": 1617538368.3486366, "EndTime": 1617538368.3486416, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 14}, "Metrics": {"validation_mse_objective": {"sum": 22.798016118068322, "count": 1, "min": 22.798016118068322, "max": 22.798016118068322}}}
#
# #metrics {"StartTime": 1617538368.348661, "EndTime": 1617538368.3486662, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 15}, "Metrics": {"validation_mse_objective": {"sum": 23.084751503140318, "count": 1, "min": 23.084751503140318, "max": 23.084751503140318}}}
#
# #metrics {"StartTime": 1617538368.348685, "EndTime": 1617538368.3486903, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 16}, "Metrics": {"validation_mse_objective": {"sum": 34.893286611519606, "count": 1, "min": 34.893286611519606, "max": 34.893286611519606}}}
#
# #metrics {"StartTime": 1617538368.348719, "EndTime": 1617538368.3487275, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 17}, "Metrics": {"validation_mse_objective": {"sum": 40.129261690027576, "count": 1, "min": 40.129261690027576, "max": 40.129261690027576}}}
#
# #metrics {"StartTime": 1617538368.3487597, "EndTime": 1617538368.348768, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 18}, "Metrics": {"validation_mse_objective": {"sum": 38.16263236251532, "count": 1, "min": 38.16263236251532, "max": 38.16263236251532}}}
#
# #metrics {"StartTime": 1617538368.3487952, "EndTime": 1617538368.3488038, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 19}, "Metrics": {"validation_mse_objective": {"sum": 37.89099599800858, "count": 1, "min": 37.89099599800858, "max": 37.89099599800858}}}
#
# #metrics {"StartTime": 1617538368.3488317, "EndTime": 1617538368.3488383, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 20}, "Metrics": {"validation_mse_objective": {"sum": 23.13649615119485, "count": 1, "min": 23.13649615119485, "max": 23.13649615119485}}}
#
# #metrics {"StartTime": 1617538368.3488688, "EndTime": 1617538368.3488767, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 21}, "Metrics": {"validation_mse_objective": {"sum": 23.07202268114277, "count": 1, "min": 23.07202268114277, "max": 23.07202268114277}}}
#
# #metrics {"StartTime": 1617538368.3489108, "EndTime": 1617538368.3489196, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 22}, "Metrics": {"validation_mse_objective": {"sum": 23.424026788449755, "count": 1, "min": 23.424026788449755, "max": 23.424026788449755}}}
#
# #metrics {"StartTime": 1617538368.3489547, "EndTime": 1617538368.3489635, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 23}, "Metrics": {"validation_mse_objective": {"sum": 22.536853266697303, "count": 1, "min": 22.536853266697303, "max": 22.536853266697303}}}
#
# #metrics {"StartTime": 1617538368.3490021, "EndTime": 1617538368.3490121, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 24}, "Metrics": {"validation_mse_objective": {"sum": 53.051338943780635, "count": 1, "min": 53.051338943780635, "max": 53.051338943780635}}}
#
# #metrics {"StartTime": 1617538368.349051, "EndTime": 1617538368.3490603, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 25}, "Metrics": {"validation_mse_objective": {"sum": 53.73478668811274, "count": 1, "min": 53.73478668811274, "max": 53.73478668811274}}}
#
# #metrics {"StartTime": 1617538368.3490958, "EndTime": 1617538368.3491054, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 26}, "Metrics": {"validation_mse_objective": {"sum": 51.930532418045345, "count": 1, "min": 51.930532418045345, "max": 51.930532418045345}}}
#
# #metrics {"StartTime": 1617538368.3491397, "EndTime": 1617538368.3491492, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 27}, "Metrics": {"validation_mse_objective": {"sum": 54.52130246629902, "count": 1, "min": 54.52130246629902, "max": 54.52130246629902}}}
#
# #metrics {"StartTime": 1617538368.349187, "EndTime": 1617538368.3491955, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 28}, "Metrics": {"validation_mse_objective": {"sum": 49.3848206763174, "count": 1, "min": 49.3848206763174, "max": 49.3848206763174}}}
#
# #metrics {"StartTime": 1617538368.349229, "EndTime": 1617538368.3492382, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 29}, "Metrics": {"validation_mse_objective": {"sum": 57.42883779488358, "count": 1, "min": 57.42883779488358, "max": 57.42883779488358}}}
#
# #metrics {"StartTime": 1617538368.3492699, "EndTime": 1617538368.3492775, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 30}, "Metrics": {"validation_mse_objective": {"sum": 47.98036104090073, "count": 1, "min": 47.98036104090073, "max": 47.98036104090073}}}
#
# #metrics {"StartTime": 1617538368.3493004, "EndTime": 1617538368.3493083, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 31}, "Metrics": {"validation_mse_objective": {"sum": 53.599437040441174, "count": 1, "min": 53.599437040441174, "max": 53.599437040441174}}}
#
# [04/04/2021 12:12:48 INFO 140225025931072] #quality_metric: host=algo-1, epoch=0, validation mse_objective <loss>=35.344003714767155
# [04/04/2021 12:12:48 INFO 140225025931072] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=mse_objective, value=20.996631697112438
# [04/04/2021 12:12:48 INFO 140225025931072] Epoch 0: Loss improved. Updating best model
# [04/04/2021 12:12:48 INFO 140225025931072] Saving model for epoch: 0
# [04/04/2021 12:12:48 INFO 140225025931072] Saved checkpoint to "/tmp/tmpl1kurew9/mx-mod-0000.params"
# [04/04/2021 12:12:48 INFO 140225025931072] #progress_metric: host=algo-1, completed 6.666666666666667 % of epochs
# #metrics {"StartTime": 1617538368.0525153, "EndTime": 1617538368.3562324, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 942.0, "count": 1, "min": 942, "max": 942}, "Total Batches Seen": {"sum": 31.0, "count": 1, "min": 31, "max": 31}, "Max Records Seen Between Resets": {"sum": 455.0, "count": 1, "min": 455, "max": 455}, "Max Batches Seen Between Resets": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "Reset Count": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Number of Records Since Last Reset": {"sum": 455.0, "count": 1, "min": 455, "max": 455}, "Number of Batches Since Last Reset": {"sum": 15.0, "count": 1, "min": 15, "max": 15}}}
#
# [04/04/2021 12:12:48 INFO 140225025931072] #throughput_metric: host=algo-1, train throughput=1497.5625243753057 records/second
# #metrics {"StartTime": 1617538368.629041, "EndTime": 1617538368.629088, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"train_mse_objective": {"sum": 0.5127884575298854, "count": 1, "min": 0.5127884575298854, "max": 0.5127884575298854}}}
#
# #metrics {"StartTime": 1617538368.629147, "EndTime": 1617538368.629157, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"train_mse_objective": {"sum": 0.553962230682373, "count": 1, "min": 0.553962230682373, "max": 0.553962230682373}}}
#
# #metrics {"StartTime": 1617538368.6291885, "EndTime": 1617538368.6291952, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"train_mse_objective": {"sum": 0.5365752854517528, "count": 1, "min": 0.5365752854517528, "max": 0.5365752854517528}}}
#
# #metrics {"StartTime": 1617538368.6292222, "EndTime": 1617538368.629228, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"train_mse_objective": {"sum": 0.4716284711446081, "count": 1, "min": 0.4716284711446081, "max": 0.4716284711446081}}}
#
# #metrics {"StartTime": 1617538368.6292593, "EndTime": 1617538368.6292663, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"train_mse_objective": {"sum": 0.3697257031287466, "count": 1, "min": 0.3697257031287466, "max": 0.3697257031287466}}}
#
# #metrics {"StartTime": 1617538368.6292872, "EndTime": 1617538368.6292922, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"train_mse_objective": {"sum": 0.4423235665474619, "count": 1, "min": 0.4423235665474619, "max": 0.4423235665474619}}}
#
# #metrics {"StartTime": 1617538368.629318, "EndTime": 1617538368.6293256, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"train_mse_objective": {"sum": 0.4014425809894289, "count": 1, "min": 0.4014425809894289, "max": 0.4014425809894289}}}
#
# #metrics {"StartTime": 1617538368.6293573, "EndTime": 1617538368.6293647, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"train_mse_objective": {"sum": 0.398215580199446, "count": 1, "min": 0.398215580199446, "max": 0.398215580199446}}}
#
# #metrics {"StartTime": 1617538368.6293967, "EndTime": 1617538368.6294043, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 8}, "Metrics": {"train_mse_objective": {"sum": 0.6109549637351718, "count": 1, "min": 0.6109549637351718, "max": 0.6109549637351718}}}
#
# #metrics {"StartTime": 1617538368.6294343, "EndTime": 1617538368.629442, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 9}, "Metrics": {"train_mse_objective": {"sum": 0.5456003376415798, "count": 1, "min": 0.5456003376415798, "max": 0.5456003376415798}}}
#
# #metrics {"StartTime": 1617538368.6294756, "EndTime": 1617538368.6294851, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 10}, "Metrics": {"train_mse_objective": {"sum": 0.5167831139905112, "count": 1, "min": 0.5167831139905112, "max": 0.5167831139905112}}}
#
# #metrics {"StartTime": 1617538368.6295207, "EndTime": 1617538368.6295302, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 11}, "Metrics": {"train_mse_objective": {"sum": 0.5532842214618411, "count": 1, "min": 0.5532842214618411, "max": 0.5532842214618411}}}
#
# #metrics {"StartTime": 1617538368.62957, "EndTime": 1617538368.6295793, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 12}, "Metrics": {"train_mse_objective": {"sum": 0.4085183473570006, "count": 1, "min": 0.4085183473570006, "max": 0.4085183473570006}}}
#
# #metrics {"StartTime": 1617538368.6296184, "EndTime": 1617538368.6296282, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 13}, "Metrics": {"train_mse_objective": {"sum": 0.4555074242608888, "count": 1, "min": 0.4555074242608888, "max": 0.4555074242608888}}}
#
# #metrics {"StartTime": 1617538368.6296682, "EndTime": 1617538368.6296778, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 14}, "Metrics": {"train_mse_objective": {"sum": 0.437639203454767, "count": 1, "min": 0.437639203454767, "max": 0.437639203454767}}}
#
# #metrics {"StartTime": 1617538368.6297164, "EndTime": 1617538368.629726, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 15}, "Metrics": {"train_mse_objective": {"sum": 0.4076181799173355, "count": 1, "min": 0.4076181799173355, "max": 0.4076181799173355}}}
#
# #metrics {"StartTime": 1617538368.6297667, "EndTime": 1617538368.6297777, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 16}, "Metrics": {"train_mse_objective": {"sum": 0.5250199032681329, "count": 1, "min": 0.5250199032681329, "max": 0.5250199032681329}}}
#
# #metrics {"StartTime": 1617538368.629813, "EndTime": 1617538368.6298223, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 17}, "Metrics": {"train_mse_objective": {"sum": 0.5452134034463337, "count": 1, "min": 0.5452134034463337, "max": 0.5452134034463337}}}
#
# #metrics {"StartTime": 1617538368.6298554, "EndTime": 1617538368.6298647, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 18}, "Metrics": {"train_mse_objective": {"sum": 0.576085022517613, "count": 1, "min": 0.576085022517613, "max": 0.576085022517613}}}
#
# #metrics {"StartTime": 1617538368.6298957, "EndTime": 1617538368.6299033, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 19}, "Metrics": {"train_mse_objective": {"sum": 0.5608005459819522, "count": 1, "min": 0.5608005459819522, "max": 0.5608005459819522}}}
#
# #metrics {"StartTime": 1617538368.629934, "EndTime": 1617538368.6299436, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 20}, "Metrics": {"train_mse_objective": {"sum": 0.4984954616853169, "count": 1, "min": 0.4984954616853169, "max": 0.4984954616853169}}}
#
# #metrics {"StartTime": 1617538368.6299758, "EndTime": 1617538368.6299841, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 21}, "Metrics": {"train_mse_objective": {"sum": 0.489378816315106, "count": 1, "min": 0.489378816315106, "max": 0.489378816315106}}}
#
# #metrics {"StartTime": 1617538368.630017, "EndTime": 1617538368.630025, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 22}, "Metrics": {"train_mse_objective": {"sum": 0.49711096712521147, "count": 1, "min": 0.49711096712521147, "max": 0.49711096712521147}}}
#
# #metrics {"StartTime": 1617538368.6300569, "EndTime": 1617538368.6300647, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 23}, "Metrics": {"train_mse_objective": {"sum": 0.5003489873238972, "count": 1, "min": 0.5003489873238972, "max": 0.5003489873238972}}}
#
# #metrics {"StartTime": 1617538368.6301148, "EndTime": 1617538368.6301248, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 24}, "Metrics": {"train_mse_objective": {"sum": 0.9571612221854073, "count": 1, "min": 0.9571612221854073, "max": 0.9571612221854073}}}
#
# #metrics {"StartTime": 1617538368.6301603, "EndTime": 1617538368.630169, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 25}, "Metrics": {"train_mse_objective": {"sum": 0.9713664395468575, "count": 1, "min": 0.9713664395468575, "max": 0.9713664395468575}}}
#
# #metrics {"StartTime": 1617538368.6302028, "EndTime": 1617538368.6302114, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 26}, "Metrics": {"train_mse_objective": {"sum": 0.9311906716653279, "count": 1, "min": 0.9311906716653279, "max": 0.9311906716653279}}}
#
# #metrics {"StartTime": 1617538368.6302443, "EndTime": 1617538368.6302524, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 27}, "Metrics": {"train_mse_objective": {"sum": 0.96086899297578, "count": 1, "min": 0.96086899297578, "max": 0.96086899297578}}}
#
# #metrics {"StartTime": 1617538368.6302872, "EndTime": 1617538368.6302955, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 28}, "Metrics": {"train_mse_objective": {"sum": 0.9688181919710976, "count": 1, "min": 0.9688181919710976, "max": 0.9688181919710976}}}
#
# #metrics {"StartTime": 1617538368.6303287, "EndTime": 1617538368.6303375, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 29}, "Metrics": {"train_mse_objective": {"sum": 0.9667127047266278, "count": 1, "min": 0.9667127047266278, "max": 0.9667127047266278}}}
#
# #metrics {"StartTime": 1617538368.6303763, "EndTime": 1617538368.630385, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 30}, "Metrics": {"train_mse_objective": {"sum": 0.9391679721219199, "count": 1, "min": 0.9391679721219199, "max": 0.9391679721219199}}}
#
# #metrics {"StartTime": 1617538368.6304197, "EndTime": 1617538368.6304293, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 31}, "Metrics": {"train_mse_objective": {"sum": 0.968497804233006, "count": 1, "min": 0.968497804233006, "max": 0.968497804233006}}}
#
# [04/04/2021 12:12:48 INFO 140225025931072] #quality_metric: host=algo-1, epoch=1, train mse_objective <loss>=0.5127884575298854
# #metrics {"StartTime": 1617538368.6772883, "EndTime": 1617538368.677332, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"validation_mse_objective": {"sum": 29.82147097120098, "count": 1, "min": 29.82147097120098, "max": 29.82147097120098}}}
#
# #metrics {"StartTime": 1617538368.6773863, "EndTime": 1617538368.6773973, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"validation_mse_objective": {"sum": 32.461326449525124, "count": 1, "min": 32.461326449525124, "max": 32.461326449525124}}}
#
# #metrics {"StartTime": 1617538368.6774297, "EndTime": 1617538368.6774383, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"validation_mse_objective": {"sum": 31.50375306372549, "count": 1, "min": 31.50375306372549, "max": 31.50375306372549}}}
#
# #metrics {"StartTime": 1617538368.6774678, "EndTime": 1617538368.677476, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"validation_mse_objective": {"sum": 28.158748851102942, "count": 1, "min": 28.158748851102942, "max": 28.158748851102942}}}
#
# #metrics {"StartTime": 1617538368.677509, "EndTime": 1617538368.6775181, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"validation_mse_objective": {"sum": 18.35800350413603, "count": 1, "min": 18.35800350413603, "max": 18.35800350413603}}}
#
# #metrics {"StartTime": 1617538368.6775398, "EndTime": 1617538368.6775453, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"validation_mse_objective": {"sum": 20.335001627604168, "count": 1, "min": 20.335001627604168, "max": 20.335001627604168}}}
#
# #metrics {"StartTime": 1617538368.677565, "EndTime": 1617538368.67757, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"validation_mse_objective": {"sum": 19.828816731770832, "count": 1, "min": 19.828816731770832, "max": 19.828816731770832}}}
#
# #metrics {"StartTime": 1617538368.6775966, "EndTime": 1617538368.6776023, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"validation_mse_objective": {"sum": 20.212799072265625, "count": 1, "min": 20.212799072265625, "max": 20.212799072265625}}}
#
# #metrics {"StartTime": 1617538368.6776245, "EndTime": 1617538368.677632, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 8}, "Metrics": {"validation_mse_objective": {"sum": 36.17272709865196, "count": 1, "min": 36.17272709865196, "max": 36.17272709865196}}}
#
# #metrics {"StartTime": 1617538368.6776583, "EndTime": 1617538368.6776655, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 9}, "Metrics": {"validation_mse_objective": {"sum": 30.185184254365808, "count": 1, "min": 30.185184254365808, "max": 30.185184254365808}}}
#
# #metrics {"StartTime": 1617538368.6776922, "EndTime": 1617538368.6776998, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 10}, "Metrics": {"validation_mse_objective": {"sum": 28.834951363357842, "count": 1, "min": 28.834951363357842, "max": 28.834951363357842}}}
#
# #metrics {"StartTime": 1617538368.677731, "EndTime": 1617538368.6777396, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 11}, "Metrics": {"validation_mse_objective": {"sum": 30.55575382008272, "count": 1, "min": 30.55575382008272, "max": 30.55575382008272}}}
#
# #metrics {"StartTime": 1617538368.677773, "EndTime": 1617538368.6777818, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 12}, "Metrics": {"validation_mse_objective": {"sum": 19.94023401596967, "count": 1, "min": 19.94023401596967, "max": 19.94023401596967}}}
#
# #metrics {"StartTime": 1617538368.6778188, "EndTime": 1617538368.677828, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 13}, "Metrics": {"validation_mse_objective": {"sum": 21.06573606004902, "count": 1, "min": 21.06573606004902, "max": 21.06573606004902}}}
#
# #metrics {"StartTime": 1617538368.6778655, "EndTime": 1617538368.677874, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 14}, "Metrics": {"validation_mse_objective": {"sum": 20.793982412300856, "count": 1, "min": 20.793982412300856, "max": 20.793982412300856}}}
#
# #metrics {"StartTime": 1617538368.6779044, "EndTime": 1617538368.6779132, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 15}, "Metrics": {"validation_mse_objective": {"sum": 20.637651032092524, "count": 1, "min": 20.637651032092524, "max": 20.637651032092524}}}
#
# #metrics {"StartTime": 1617538368.6779459, "EndTime": 1617538368.6779554, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 16}, "Metrics": {"validation_mse_objective": {"sum": 28.011982038909313, "count": 1, "min": 28.011982038909313, "max": 28.011982038909313}}}
#
# #metrics {"StartTime": 1617538368.6779819, "EndTime": 1617538368.6779907, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 17}, "Metrics": {"validation_mse_objective": {"sum": 31.723163679534313, "count": 1, "min": 31.723163679534313, "max": 31.723163679534313}}}
#
# #metrics {"StartTime": 1617538368.6780212, "EndTime": 1617538368.6780288, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 18}, "Metrics": {"validation_mse_objective": {"sum": 30.08685302734375, "count": 1, "min": 30.08685302734375, "max": 30.08685302734375}}}
#
# #metrics {"StartTime": 1617538368.6780624, "EndTime": 1617538368.6780722, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 19}, "Metrics": {"validation_mse_objective": {"sum": 30.087285060508577, "count": 1, "min": 30.087285060508577, "max": 30.087285060508577}}}
#
# #metrics {"StartTime": 1617538368.6781201, "EndTime": 1617538368.6781304, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 20}, "Metrics": {"validation_mse_objective": {"sum": 19.759317435470283, "count": 1, "min": 19.759317435470283, "max": 19.759317435470283}}}
#
# #metrics {"StartTime": 1617538368.678165, "EndTime": 1617538368.678175, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 21}, "Metrics": {"validation_mse_objective": {"sum": 19.4489273370481, "count": 1, "min": 19.4489273370481, "max": 19.4489273370481}}}
#
# #metrics {"StartTime": 1617538368.6782084, "EndTime": 1617538368.678218, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 22}, "Metrics": {"validation_mse_objective": {"sum": 19.577961641199447, "count": 1, "min": 19.577961641199447, "max": 19.577961641199447}}}
#
# #metrics {"StartTime": 1617538368.6782515, "EndTime": 1617538368.678261, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 23}, "Metrics": {"validation_mse_objective": {"sum": 20.116534663181678, "count": 1, "min": 20.116534663181678, "max": 20.116534663181678}}}
#
# #metrics {"StartTime": 1617538368.6782963, "EndTime": 1617538368.6783066, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 24}, "Metrics": {"validation_mse_objective": {"sum": 52.38705145143995, "count": 1, "min": 52.38705145143995, "max": 52.38705145143995}}}
#
# #metrics {"StartTime": 1617538368.6783395, "EndTime": 1617538368.6783493, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 25}, "Metrics": {"validation_mse_objective": {"sum": 53.827107747395836, "count": 1, "min": 53.827107747395836, "max": 53.827107747395836}}}
#
# #metrics {"StartTime": 1617538368.6783826, "EndTime": 1617538368.6783922, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 26}, "Metrics": {"validation_mse_objective": {"sum": 53.50772633272059, "count": 1, "min": 53.50772633272059, "max": 53.50772633272059}}}
#
# #metrics {"StartTime": 1617538368.6784253, "EndTime": 1617538368.6784346, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 27}, "Metrics": {"validation_mse_objective": {"sum": 53.35400390625, "count": 1, "min": 53.35400390625, "max": 53.35400390625}}}
#
# #metrics {"StartTime": 1617538368.678471, "EndTime": 1617538368.678481, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 28}, "Metrics": {"validation_mse_objective": {"sum": 54.005512312346816, "count": 1, "min": 54.005512312346816, "max": 54.005512312346816}}}
#
# #metrics {"StartTime": 1617538368.6785102, "EndTime": 1617538368.6785188, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 29}, "Metrics": {"validation_mse_objective": {"sum": 54.153217390471816, "count": 1, "min": 54.153217390471816, "max": 54.153217390471816}}}
#
# ...
#
# #metrics {"StartTime": 1617538372.907152, "EndTime": 1617538372.9071612, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 28}, "Metrics": {"train_mse_objective": {"sum": 0.9692702208246503, "count": 1, "min": 0.9692702208246503, "max": 0.9692702208246503}}}
#
# #metrics {"StartTime": 1617538372.9071925, "EndTime": 1617538372.9072003, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 29}, "Metrics": {"train_mse_objective": {"sum": 0.9680116559777941, "count": 1, "min": 0.9680116559777941, "max": 0.9680116559777941}}}
#
# #metrics {"StartTime": 1617538372.907231, "EndTime": 1617538372.90724, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 30}, "Metrics": {"train_mse_objective": {"sum": 0.9716038235596248, "count": 1, "min": 0.9716038235596248, "max": 0.9716038235596248}}}
#
# #metrics {"StartTime": 1617538372.9072728, "EndTime": 1617538372.9072804, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 31}, "Metrics": {"train_mse_objective": {"sum": 0.9682713491576058, "count": 1, "min": 0.9682713491576058, "max": 0.9682713491576058}}}
#
# [04/04/2021 12:12:52 INFO 140225025931072] #quality_metric: host=algo-1, epoch=14, train mse_objective <loss>=0.26231017389467787
# #metrics {"StartTime": 1617538372.9525576, "EndTime": 1617538372.952603, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 0}, "Metrics": {"validation_mse_objective": {"sum": 14.218086990655637, "count": 1, "min": 14.218086990655637, "max": 14.218086990655637}}}
#
# #metrics {"StartTime": 1617538372.952663, "EndTime": 1617538372.9526753, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 1}, "Metrics": {"validation_mse_objective": {"sum": 14.749240650850183, "count": 1, "min": 14.749240650850183, "max": 14.749240650850183}}}
#
# #metrics {"StartTime": 1617538372.9527168, "EndTime": 1617538372.9527273, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 2}, "Metrics": {"validation_mse_objective": {"sum": 14.42402738683364, "count": 1, "min": 14.42402738683364, "max": 14.42402738683364}}}
#
# #metrics {"StartTime": 1617538372.9527645, "EndTime": 1617538372.9527757, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 3}, "Metrics": {"validation_mse_objective": {"sum": 14.6558837890625, "count": 1, "min": 14.6558837890625, "max": 14.6558837890625}}}
#
# #metrics {"StartTime": 1617538372.9528086, "EndTime": 1617538372.9528167, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 4}, "Metrics": {"validation_mse_objective": {"sum": 18.46704759784773, "count": 1, "min": 18.46704759784773, "max": 18.46704759784773}}}
#
# #metrics {"StartTime": 1617538372.952847, "EndTime": 1617538372.9528556, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 5}, "Metrics": {"validation_mse_objective": {"sum": 18.68320420209099, "count": 1, "min": 18.68320420209099, "max": 18.68320420209099}}}
#
# #metrics {"StartTime": 1617538372.9528892, "EndTime": 1617538372.9528985, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 6}, "Metrics": {"validation_mse_objective": {"sum": 18.46872127757353, "count": 1, "min": 18.46872127757353, "max": 18.46872127757353}}}
#
# #metrics {"StartTime": 1617538372.9529262, "EndTime": 1617538372.9529326, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 7}, "Metrics": {"validation_mse_objective": {"sum": 18.74055690391391, "count": 1, "min": 18.74055690391391, "max": 18.74055690391391}}}
#
# #metrics {"StartTime": 1617538372.9529524, "EndTime": 1617538372.9529574, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 8}, "Metrics": {"validation_mse_objective": {"sum": 13.48762482287837, "count": 1, "min": 13.48762482287837, "max": 13.48762482287837}}}
#
# #metrics {"StartTime": 1617538372.952988, "EndTime": 1617538372.9529953, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 9}, "Metrics": {"validation_mse_objective": {"sum": 14.073514452167586, "count": 1, "min": 14.073514452167586, "max": 14.073514452167586}}}
#
# #metrics {"StartTime": 1617538372.9530284, "EndTime": 1617538372.9530363, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 10}, "Metrics": {"validation_mse_objective": {"sum": 13.75909304151348, "count": 1, "min": 13.75909304151348, "max": 13.75909304151348}}}
#
# #metrics {"StartTime": 1617538372.953071, "EndTime": 1617538372.9530802, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 11}, "Metrics": {"validation_mse_objective": {"sum": 13.873929491230086, "count": 1, "min": 13.873929491230086, "max": 13.873929491230086}}}
#
# #metrics {"StartTime": 1617538372.9531136, "EndTime": 1617538372.9531226, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 12}, "Metrics": {"validation_mse_objective": {"sum": 17.769703584558822, "count": 1, "min": 17.769703584558822, "max": 17.769703584558822}}}
#
# #metrics {"StartTime": 1617538372.9531555, "EndTime": 1617538372.9531643, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 13}, "Metrics": {"validation_mse_objective": {"sum": 17.941805372051164, "count": 1, "min": 17.941805372051164, "max": 17.941805372051164}}}
#
# #metrics {"StartTime": 1617538372.9531913, "EndTime": 1617538372.9531972, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 14}, "Metrics": {"validation_mse_objective": {"sum": 17.795663871017158, "count": 1, "min": 17.795663871017158, "max": 17.795663871017158}}}
#
# #metrics {"StartTime": 1617538372.9532182, "EndTime": 1617538372.953226, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 15}, "Metrics": {"validation_mse_objective": {"sum": 18.008491067325366, "count": 1, "min": 18.008491067325366, "max": 18.008491067325366}}}
#
# #metrics {"StartTime": 1617538372.9532602, "EndTime": 1617538372.9532685, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 16}, "Metrics": {"validation_mse_objective": {"sum": 18.834832883348653, "count": 1, "min": 18.834832883348653, "max": 18.834832883348653}}}
#
# #metrics {"StartTime": 1617538372.9533048, "EndTime": 1617538372.953314, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 17}, "Metrics": {"validation_mse_objective": {"sum": 18.873145009957106, "count": 1, "min": 18.873145009957106, "max": 18.873145009957106}}}
#
# #metrics {"StartTime": 1617538372.953353, "EndTime": 1617538372.953363, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 18}, "Metrics": {"validation_mse_objective": {"sum": 18.823179357192096, "count": 1, "min": 18.823179357192096, "max": 18.823179357192096}}}
#
# #metrics {"StartTime": 1617538372.953399, "EndTime": 1617538372.9534082, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 19}, "Metrics": {"validation_mse_objective": {"sum": 18.854327033547793, "count": 1, "min": 18.854327033547793, "max": 18.854327033547793}}}
#
# #metrics {"StartTime": 1617538372.953447, "EndTime": 1617538372.9534566, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 20}, "Metrics": {"validation_mse_objective": {"sum": 20.163548488242952, "count": 1, "min": 20.163548488242952, "max": 20.163548488242952}}}
#
# #metrics {"StartTime": 1617538372.9534955, "EndTime": 1617538372.9535046, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 21}, "Metrics": {"validation_mse_objective": {"sum": 20.58018643248315, "count": 1, "min": 20.58018643248315, "max": 20.58018643248315}}}
#
# #metrics {"StartTime": 1617538372.9535449, "EndTime": 1617538372.9535558, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 22}, "Metrics": {"validation_mse_objective": {"sum": 20.156181185853246, "count": 1, "min": 20.156181185853246, "max": 20.156181185853246}}}
#
# #metrics {"StartTime": 1617538372.9535887, "EndTime": 1617538372.9535966, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 23}, "Metrics": {"validation_mse_objective": {"sum": 20.548971138748467, "count": 1, "min": 20.548971138748467, "max": 20.548971138748467}}}
#
# #metrics {"StartTime": 1617538372.9536316, "EndTime": 1617538372.9536405, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 24}, "Metrics": {"validation_mse_objective": {"sum": 53.00674498314951, "count": 1, "min": 53.00674498314951, "max": 53.00674498314951}}}
#
# #metrics {"StartTime": 1617538372.953677, "EndTime": 1617538372.9536855, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 25}, "Metrics": {"validation_mse_objective": {"sum": 52.908866134344365, "count": 1, "min": 52.908866134344365, "max": 52.908866134344365}}}
#
# #metrics {"StartTime": 1617538372.9537168, "EndTime": 1617538372.9537253, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 26}, "Metrics": {"validation_mse_objective": {"sum": 53.122673483455884, "count": 1, "min": 53.122673483455884, "max": 53.122673483455884}}}
#
# #metrics {"StartTime": 1617538372.9537625, "EndTime": 1617538372.9537723, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 27}, "Metrics": {"validation_mse_objective": {"sum": 53.14959597120098, "count": 1, "min": 53.14959597120098, "max": 53.14959597120098}}}
#
# #metrics {"StartTime": 1617538372.95381, "EndTime": 1617538372.9538186, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 28}, "Metrics": {"validation_mse_objective": {"sum": 53.91018497242647, "count": 1, "min": 53.91018497242647, "max": 53.91018497242647}}}
#
# #metrics {"StartTime": 1617538372.9538534, "EndTime": 1617538372.9538627, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 29}, "Metrics": {"validation_mse_objective": {"sum": 52.82803643918505, "count": 1, "min": 52.82803643918505, "max": 52.82803643918505}}}
#
# #metrics {"StartTime": 1617538372.9538867, "EndTime": 1617538372.9538925, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 30}, "Metrics": {"validation_mse_objective": {"sum": 54.5668275122549, "count": 1, "min": 54.5668275122549, "max": 54.5668275122549}}}
#
# #metrics {"StartTime": 1617538372.9539115, "EndTime": 1617538372.953917, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 31}, "Metrics": {"validation_mse_objective": {"sum": 53.03503657322304, "count": 1, "min": 53.03503657322304, "max": 53.03503657322304}}}
#
# [04/04/2021 12:12:52 INFO 140225025931072] #quality_metric: host=algo-1, epoch=14, validation mse_objective <loss>=14.218086990655637
# [04/04/2021 12:12:52 INFO 140225025931072] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=mse_objective, value=13.48762482287837
# [04/04/2021 12:12:52 INFO 140225025931072] Epoch 14: Loss improved. Updating best model
# [04/04/2021 12:12:52 INFO 140225025931072] Saving model for epoch: 14
# [04/04/2021 12:12:52 INFO 140225025931072] Saved checkpoint to "/tmp/tmp0v8tn9al/mx-mod-0000.params"
# [04/04/2021 12:12:52 INFO 140225025931072] #progress_metric: host=algo-1, completed 100.0 % of epochs
# #metrics {"StartTime": 1617538372.6609483, "EndTime": 1617538372.959385, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 7312.0, "count": 1, "min": 7312, "max": 7312}, "Total Batches Seen": {"sum": 241.0, "count": 1, "min": 241, "max": 241}, "Max Records Seen Between Resets": {"sum": 455.0, "count": 1, "min": 455, "max": 455}, "Max Batches Seen Between Resets": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "Reset Count": {"sum": 17.0, "count": 1, "min": 17, "max": 17}, "Number of Records Since Last Reset": {"sum": 455.0, "count": 1, "min": 455, "max": 455}, "Number of Batches Since Last Reset": {"sum": 15.0, "count": 1, "min": 15, "max": 15}}}
#
# [04/04/2021 12:12:52 INFO 140225025931072] #throughput_metric: host=algo-1, train throughput=1524.0991091358499 records/second
# [04/04/2021 12:12:52 WARNING 140225025931072] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [04/04/2021 12:12:52 WARNING 140225025931072] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [04/04/2021 12:12:53 INFO 140225025931072] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=mse_objective, value=13.48762482287837
# [04/04/2021 12:12:53 INFO 140225025931072] #validation_score (algo-1) : ('mse_objective', 13.48762482287837)
# [04/04/2021 12:12:53 INFO 140225025931072] #validation_score (algo-1) : ('mse', 13.48762482287837)
# [04/04/2021 12:12:53 INFO 140225025931072] #validation_score (algo-1) : ('absolute_loss', 2.739444283878102)
# [04/04/2021 12:12:53 INFO 140225025931072] #quality_metric: host=algo-1, validation mse_objective <loss>=13.48762482287837
# [04/04/2021 12:12:53 INFO 140225025931072] #quality_metric: host=algo-1, validation mse <loss>=13.48762482287837
# [04/04/2021 12:12:53 INFO 140225025931072] #quality_metric: host=algo-1, validation absolute_loss <loss>=2.739444283878102
# [04/04/2021 12:12:53 INFO 140225025931072] Best model found for hyperparameters: {"optimizer": "adam", "learning_rate": 0.005, "wd": 0.01, "l1": 0.0, "lr_scheduler_step": 10, "lr_scheduler_factor": 0.99, "lr_scheduler_minimum_lr": 1e-05}
# [04/04/2021 12:12:53 INFO 140225025931072] Saved checkpoint to "/tmp/tmpae78c74a/mx-mod-0000.params"
# [04/04/2021 12:12:53 INFO 140225025931072] Test data is not provided.
# #metrics {"StartTime": 1617538367.7974768, "EndTime": 1617538373.0201879, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 243.16000938415527, "count": 1, "min": 243.16000938415527, "max": 243.16000938415527}, "epochs": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "check_early_stopping.time": {"sum": 9.942054748535156, "count": 16, "min": 0.1544952392578125, "max": 1.0988712310791016}, "update.time": {"sum": 4857.535123825073, "count": 15, "min": 291.5985584259033, "max": 428.6928176879883}, "finalize.time": {"sum": 55.99212646484375, "count": 1, "min": 55.99212646484375, "max": 55.99212646484375}, "setuptime": {"sum": 19.413471221923828, "count": 1, "min": 19.413471221923828, "max": 19.413471221923828}, "totaltime": {"sum": 5406.638860702515, "count": 1, "min": 5406.638860702515, "max": 5406.638860702515}}}
#
#
# 2021-04-04 12:13:20 Completed - Training job completed
# Training seconds: 50
# Billable seconds: 50

# %%
from time import strftime, gmtime
timestamp = strftime('%d-%H-%M-%S', gmtime())
endpoint_name = 'linear-learner-demo-'+timestamp
print(endpoint_name)
# Out:
# linear-learner-demo-04-12-13-53

# %%
ll_predictor = ll_estimator.deploy(
    endpoint_name=endpoint_name,
    initial_instance_count=1,
    instance_type='ml.t2.medium')
# Out:
# -------------------!

# %%
#ll_predictor.content_type = 'text/csv'
ll_predictor.serializer = sagemaker.serializers.CSVSerializer()
ll_predictor.deserializer = sagemaker.deserializers.CSVDeserializer()
test_sample = '0.00632, 18, 2.31, 0, 0.538, 6.575, 65.2, 4.09, 1, 296, 15.3, 396.9, 4.98, 24'
response = ll_predictor.predict(test_sample)
print(response)
# Out:
# [['-61.887508392333984']]

# %%
test_samples = ["0.14455, 12.5, 7.87, 0, 0.524, 6.172,96.1, 5.9505, 5, 311, 15.2, 396.9, 19.15, 27.1"]
response = ll_predictor.predict(test_samples)
print(response)
# Out:
# [['75.16258239746094']]

# %%
ll_predictor.delete_endpoint()
